# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_pickle("../data/multi_label_train_v0.3.pkl")
df
# Out:
#                                                        url  \
# 0        https://localtvwtkr.files.wordpress.com/2018/0...
# 1        https://www.earthmagazine.org/sites/earthmagaz...
# 2        https://s-media-cache-ak0.pinimg.com/originals...
# 3        https://m.gjcdn.net/screenshot-thumbnail/300x3...
# 4        http://nnimgt-a.akamaihd.net/transform/v1/crop...
# ...                                                    ...
# 1608667  https://upload.wikimedia.org/wikipedia/commons...
# 1608668  http://images.newindianexpress.com/uploads/use...
# 1608669  https://savepetesharbor.files.wordpress.com/20...
# 1608670  https://i1.ytimg.com/vi/pdyzTYH1L5Q/hqdefault.jpg
# 1608671  https://thumb9.shutterstock.com/display_pic_wi...
#
#                                                  incidents  \
# 0        {'snow covered': 1, 'ice storm': 0, 'hailstorm...
# 1                                           {'flooded': 1}
# 2                                    {'truck accident': 0}
# 3                                         {'hailstorm': 0}
# 4        {'blocked': 1, 'with smoke': 0, 'under constru...
# ...                                                    ...
# 1608667                                         {'fog': 1}
# 1608668                                {'snow covered': 1}
# 1608669            {'flooded': 0, 'under construction': 0}
# 1608670                                     {'on fire': 1}
# 1608671                                   {'landslide': 1}
#
#                                                     places  \
# 0                {'parking lot': 0, 'building outdoor': 1}
# 1         {'field': 0, 'street': 1, 'building outdoor': 0}
# 2                                                       {}
# 3                                                       {}
# 4        {'construction site': 0, 'skyscraper': 0, 'dow...
# ...                                                    ...
# 1608667                         {'street': 0, 'forest': 0}
# 1608668  {'port': 0, 'ocean': 0, 'glacier': 0, 'coast': 1}
# 1608669                                                 {}
# 1608670  {'industrial area': 1, 'downtown': 0, 'buildin...
# 1608671       {'desert': 0, 'forest road': 1, 'forest': 0}
#
#                                      image_id  \
# 0                                         404
# 1                                         404
# 2        e6a54564-0082-4a26-9df4-13fe39f8ec15
# 3                                         404
# 4                                         400
# ...                                       ...
# 1608667                                   403
# 1608668  93c26672-dba8-4f3c-ab66-9a426c9b05f8
# 1608669  aee52b54-05cc-444b-b410-e5b0ef870c74
# 1608670  c21faea6-5060-4f3f-9d2e-a8b65cfa0f74
# 1608671  80d7afe1-fb86-4925-8cb4-f0a25961c44b
#
#                                                    key  downloadable  \
# 0                winter_storm_in_parking_lot_00361.jpg         False
# 1                coastal_flood_in_field_road_00296.jpg         False
# 2        track_crash_in_library_outdoor_af9881c12a.jpg          True
# 3                      hailstorm_in_dam_b6ec75ec51.jpg         False
# 4             blocked_construction_site_094b6eef1a.jpg         False
# ...                                                ...           ...
# 1608667              van_wreck_in_alley_564c55a4a6.jpg         False
# 1608668               oil_spill_in_port_3bfea2121a.jpg          True
# 1608669                       blocked_harbor_00122.jpg          True
# 1608670         wild_fire_in_industrial_area_00230.jpg          True
# 1608671   mudslide_in_desert_vegetation_e058c1d8b9.jpg          True
#
#         incidents_list                 places_list
# 0         snow covered            building outdoor
# 1              flooded                      street
# 2              unknown                     unknown
# 3              unknown                     unknown
# 4              blocked  building outdoor, downtown
# ...                ...                         ...
# 1608667            fog                     unknown
# 1608668   snow covered                       coast
# 1608669        unknown                     unknown
# 1608670        on fire             industrial area
# 1608671      landslide                 forest road
#
# [1608672 rows x 8 columns]

# %%
df = df[df.downloadable == True]
df
# Out:
#                                                        url  \
# 2        https://s-media-cache-ak0.pinimg.com/originals...
# 5        https://depts.washington.edu/cspn/wordpress/wp...
# 6        http://static.stuff.co.nz/files/whakatanedamag...
# 7        https://chicago.cbslocal.com/wp-content/upload...
# 8        https://www.storm-solutions.net/hs-fs/hubfs/At...
# ...                                                    ...
# 1608666  https://previews.agefotostock.com/previewimage...
# 1608668  http://images.newindianexpress.com/uploads/use...
# 1608669  https://savepetesharbor.files.wordpress.com/20...
# 1608670  https://i1.ytimg.com/vi/pdyzTYH1L5Q/hqdefault.jpg
# 1608671  https://thumb9.shutterstock.com/display_pic_wi...
#
#                                                  incidents  \
# 2                                    {'truck accident': 0}
# 5                                        {'earthquake': 1}
# 6        {'tropical cyclone': 1, 'mudslide mudflow': 0,...
# 7                    {'car accident': 1, 'traffic jam': 0}
# 8        {'mudslide mudflow': 0, 'flooded': 0, 'dirty c...
# ...                                                    ...
# 1608666  {'with smoke': 0, 'under construction': 0, 'he...
# 1608668                                {'snow covered': 1}
# 1608669            {'flooded': 0, 'under construction': 0}
# 1608670                                     {'on fire': 1}
# 1608671                                   {'landslide': 1}
#
#                                                     places  \
# 2                                                       {}
# 5        {'excavation': 0, 'village': 1, 'building outd...
# 6        {'building outdoor': 0, 'forest road': 1, 'for...
# 7        {'river': 0, 'street': 1, 'downtown': 0, 'buil...
# 8                                                       {}
# ...                                                    ...
# 1608666  {'building facade': 1, 'sky': 0, 'building out...
# 1608668  {'port': 0, 'ocean': 0, 'glacier': 0, 'coast': 1}
# 1608669                                                 {}
# 1608670  {'industrial area': 1, 'downtown': 0, 'buildin...
# 1608671       {'desert': 0, 'forest road': 1, 'forest': 0}
#
#                                      image_id  \
# 2        e6a54564-0082-4a26-9df4-13fe39f8ec15
# 5        8ef207d8-0e84-448d-86bd-0475426618b9
# 6        de47d951-0f4e-4361-93b7-9bf5f67919a2
# 7        97ddfd3c-ae2d-48db-9343-ab76f80fd3d1
# 8        cfebd146-2eaa-422c-b86a-0f64a571573b
# ...                                       ...
# 1608666  a3bc68f1-3047-4679-9dab-0ba9d742da75
# 1608668  93c26672-dba8-4f3c-ab66-9a426c9b05f8
# 1608669  aee52b54-05cc-444b-b410-e5b0ef870c74
# 1608670  c21faea6-5060-4f3f-9d2e-a8b65cfa0f74
# 1608671  80d7afe1-fb86-4925-8cb4-f0a25961c44b
#
#                                                    key  downloadable  \
# 2        track_crash_in_library_outdoor_af9881c12a.jpg          True
# 5                    snowslide_in_excavation_00397.jpg          True
# 6          cyclone_in_desert_vegetation_d6340a08d6.jpg          True
# 7                         car_crash_in_river_00617.jpg          True
# 8                    hurricaine_in_shopfront_00094.jpg          True
# ...                                                ...           ...
# 1608666            destroyed_building_facade_00033.jpg          True
# 1608668               oil_spill_in_port_3bfea2121a.jpg          True
# 1608669                       blocked_harbor_00122.jpg          True
# 1608670         wild_fire_in_industrial_area_00230.jpg          True
# 1608671   mudslide_in_desert_vegetation_e058c1d8b9.jpg          True
#
#                       incidents_list                places_list
# 2                            unknown                    unknown
# 5                         earthquake  building outdoor, village
# 6        landslide, tropical cyclone        forest, forest road
# 7                       car accident                     street
# 8                            unknown                    unknown
# ...                              ...                        ...
# 1608666                      derecho            building facade
# 1608668                 snow covered                      coast
# 1608669                      unknown                    unknown
# 1608670                      on fire            industrial area
# 1608671                    landslide                forest road
#
# [1276038 rows x 8 columns]

# %%
incidents = df["incidents_list"].value_counts()[1:]
places = df["places_list"].value_counts()[1:]

relative_incident_frequency = incidents / incidents.sum()
relative_place_frequency = places / places.sum()

n = 1000

# Change the random seed of numpy to n
np.random.seed(n)

# Get n samples from df maintaining the relative frequency of incidents
incident_samples = np.random.choice(relative_incident_frequency.index, size=n // 2, p=relative_incident_frequency.values)
incident_samples.sort()

places_samples = np.random.choice(relative_place_frequency.index, size=n // 2, p=relative_place_frequency.values)
places_samples.sort()

incident_samples
# Out:
# array(['airplane accident', 'airplane accident', 'airplane accident',
#        'airplane accident', 'airplane accident', 'airplane accident',
#        'airplane accident', 'airplane accident', 'airplane accident',
#        'airplane accident', 'airplane accident',
#        'airplane accident, damaged', 'bicycle accident',
#        'bicycle accident', 'blocked', 'blocked', 'blocked', 'blocked',
#        'blocked', 'blocked', 'blocked', 'blocked', 'blocked', 'blocked',
#        'blocked', 'blocked', 'blocked', 'blocked', 'blocked', 'blocked',
#        'blocked', 'blocked, burned', 'blocked, burned, damaged',
#        'blocked, collapsed, under construction', 'blocked, earthquake',
#        'blocked, flooded, heavy rainfall', 'blocked, traffic jam',
#        'blocked, traffic jam', 'blocked, tropical cyclone',
#        'blocked, under construction', 'burned', 'burned', 'burned',
#        'burned', 'burned', 'burned', 'burned, bus accident, drought',
#        'burned, car accident', 'burned, car accident, van accident',
#        'burned, damaged', 'burned, damaged',
#        'burned, damaged, on fire, with smoke',
#        'burned, dust devil, with smoke', 'burned, fire whirl, on fire',
#        'burned, on fire', 'burned, on fire, wildfire',
#        'burned, on fire, wildfire, with smoke',
#        'burned, on fire, wildfire, with smoke',
#        'burned, ship boat accident', 'burned, wildfire',
#        'burned, wildfire, with smoke', 'burned, with smoke',
#        'burned, with smoke', 'bus accident', 'bus accident',
#        'bus accident',
#        'bus accident, car accident, collapsed, earthquake',
#        'bus accident, car accident, train accident',
#        'bus accident, car accident, truck accident, van accident',
#        'bus accident, car accident, van accident',
#        'bus accident, collapsed', 'car accident', 'car accident',
#        'car accident', 'car accident', 'car accident', 'car accident',
#        'car accident', 'car accident', 'car accident', 'car accident',
#        'car accident', 'car accident', 'car accident', 'car accident',
#        'car accident, damaged', 'car accident, damaged, van accident',
#        'car accident, dirty contamined',
#        'car accident, motorcycle accident',
#        'car accident, motorcycle accident',
#        'car accident, motorcycle accident',
#        'car accident, truck accident',
#        'car accident, truck accident, van accident',
#        'car accident, truck accident, van accident',
#        'car accident, van accident', 'car accident, van accident',
#        'car accident, van accident', 'car accident, van accident',
#        'car accident, van accident', 'collapsed', 'collapsed',
#        'collapsed', 'collapsed', 'collapsed', 'collapsed', 'collapsed',
#        'collapsed', 'collapsed', 'collapsed, damaged',
#        'collapsed, damaged, earthquake', 'collapsed, damaged, earthquake',
#        'collapsed, damaged, earthquake, under construction',
#        'collapsed, damaged, flooded, tropical cyclone',
#        'collapsed, dirty contamined, earthquake',
#        'collapsed, earthquake, flooded',
#        'collapsed, earthquake, with smoke',
#        'collapsed, ship boat accident', 'collapsed, train accident',
#        'collapsed, train accident', 'collapsed, train accident',
#        'collapsed, under construction', 'collapsed, under construction',
#        'collapsed, wildfire', 'collapsed, with smoke',
#        'collapsed, with smoke', 'damaged', 'damaged', 'damaged',
#        'damaged', 'damaged', 'damaged', 'damaged', 'damaged, drought',
#        'damaged, earthquake', 'damaged, earthquake',
#        'damaged, earthquake', 'damaged, earthquake, mudslide mudflow',
#        'damaged, flooded', 'damaged, flooded', 'damaged, landslide',
#        'damaged, mudslide mudflow', 'damaged, on fire', 'derecho',
#        'derecho', 'derecho', 'derecho', 'derecho, flooded',
#        'derecho, thunderstorm', 'derecho, volcanic eruption, wildfire',
#        'dirty contamined', 'dirty contamined', 'dirty contamined',
#        'dirty contamined', 'dirty contamined', 'dirty contamined',
#        'dirty contamined', 'dirty contamined', 'dirty contamined',
#        'dirty contamined', 'dirty contamined', 'dirty contamined',
#        'dirty contamined, earthquake', 'dirty contamined, oil spill',
#        'dirty contamined, tropical cyclone',
#        'dirty contamined, under construction',
#        'dirty contamined, under construction',
#        'dirty contamined, under construction', 'drought', 'drought',
#        'drought', 'drought', 'drought', 'drought', 'drought', 'drought',
#        'drought', 'drought', 'drought', 'drought', 'drought', 'drought',
#        'drought', 'drought', 'drought', 'drought', 'drought', 'drought',
#        'drought', 'drought', 'drought', 'drought',
#        'drought, dust sand storm', 'drought, landslide',
#        'drought, mudslide mudflow', 'drought, with smoke',
#        'dust devil, thunderstorm, tornado', 'dust devil, tornado',
#        'dust devil, with smoke', 'dust sand storm', 'dust sand storm',
#        'dust sand storm', 'dust sand storm', 'dust sand storm',
#        'dust sand storm', 'dust sand storm', 'dust sand storm',
#        'dust sand storm', 'dust sand storm, fog', 'dust sand storm, fog',
#        'dust sand storm, fog', 'dust sand storm, train accident',
#        'dust sand storm, with smoke', 'earthquake', 'earthquake',
#        'earthquake', 'earthquake', 'earthquake', 'earthquake',
#        'earthquake', 'earthquake, mudslide mudflow',
#        'fire whirl, on fire, wildfire', 'flooded', 'flooded', 'flooded',
#        'flooded', 'flooded', 'flooded', 'flooded', 'flooded', 'flooded',
#        'flooded', 'flooded', 'flooded', 'flooded', 'flooded', 'flooded',
#        'flooded', 'flooded', 'flooded', 'flooded', 'flooded', 'flooded',
#        'flooded', 'flooded', 'flooded', 'flooded', 'flooded', 'flooded',
#        'flooded', 'flooded', 'flooded', 'flooded', 'flooded', 'flooded',
#        'flooded', 'flooded', 'flooded', 'flooded', 'flooded', 'flooded',
#        'flooded', 'flooded', 'flooded', 'flooded, fog, heavy rainfall',
#        'flooded, heavy rainfall', 'flooded, heavy rainfall',
#        'flooded, heavy rainfall', 'flooded, heavy rainfall',
#        'flooded, heavy rainfall', 'flooded, mudslide mudflow',
#        'flooded, mudslide mudflow', 'flooded, mudslide mudflow',
#        'flooded, oil spill', 'flooded, tropical cyclone',
#        'flooded, truck accident', 'fog', 'fog', 'fog', 'fog', 'fog',
#        'fog', 'fog', 'fog', 'fog', 'fog', 'fog', 'fog', 'fog',
#        'fog, heavy rainfall', 'fog, snow covered', 'fog, snow covered',
#        'fog, snow covered', 'hailstorm', 'hailstorm', 'hailstorm',
#        'hailstorm', 'hailstorm', 'hailstorm, snow covered',
#        'heavy rainfall', 'heavy rainfall', 'heavy rainfall',
#        'heavy rainfall', 'heavy rainfall, tropical cyclone', 'ice storm',
#        'ice storm', 'ice storm, snow covered', 'ice storm, snow covered',
#        'ice storm, snow covered', 'ice storm, snow covered',
#        'ice storm, snow covered', 'landslide',
#        'landslide, rockslide rockfall', 'motorcycle accident',
#        'motorcycle accident', 'motorcycle accident',
#        'motorcycle accident', 'motorcycle accident',
#        'motorcycle accident', 'motorcycle accident',
#        'motorcycle accident', 'mudslide mudflow',
#        'nuclear explosion, on fire',
#        'nuclear explosion, volcanic eruption',
#        'nuclear explosion, with smoke', 'oil spill', 'oil spill',
#        'oil spill', 'oil spill, snow covered', 'on fire', 'on fire',
#        'on fire', 'on fire', 'on fire', 'on fire', 'on fire', 'on fire',
#        'on fire', 'on fire', 'on fire', 'on fire', 'on fire, wildfire',
#        'on fire, wildfire', 'on fire, wildfire',
#        'on fire, wildfire, with smoke', 'on fire, wildfire, with smoke',
#        'on fire, with smoke', 'on fire, with smoke',
#        'on fire, with smoke', 'rockslide rockfall', 'ship boat accident',
#        'ship boat accident', 'ship boat accident', 'ship boat accident',
#        'ship boat accident', 'ship boat accident', 'sinkhole', 'sinkhole',
#        'sinkhole', 'sinkhole, under construction', 'snow covered',
#        'snow covered', 'snow covered', 'snow covered', 'snow covered',
#        'snow covered', 'snow covered', 'snow covered', 'snow covered',
#        'snow covered', 'snow covered', 'snow covered', 'snow covered',
#        'snow covered', 'snow covered', 'snow covered', 'snow covered',
#        'snow covered', 'snow covered', 'snow covered', 'snow covered',
#        'snow covered', 'snow covered', 'snow covered', 'snow covered',
#        'snow covered', 'snow covered', 'snow covered', 'snow covered',
#        'snow covered', 'snow covered', 'snow covered', 'snow covered',
#        'snow covered', 'snow covered', 'snow covered', 'snow covered',
#        'snow covered', 'snow covered', 'snow covered', 'snow covered',
#        'snow covered', 'snow covered', 'snow covered', 'snow covered',
#        'snow covered', 'snow covered', 'snow covered', 'snow covered',
#        'snow covered', 'snow covered',
#        'snow covered, snowslide avalanche',
#        'snow covered, snowslide avalanche',
#        'snow covered, under construction', 'snow covered, with smoke',
#        'storm surge', 'storm surge', 'storm surge, tropical cyclone',
#        'storm surge, tropical cyclone', 'thunderstorm', 'thunderstorm',
#        'thunderstorm', 'thunderstorm', 'thunderstorm', 'thunderstorm',
#        'traffic jam', 'traffic jam', 'traffic jam', 'traffic jam',
#        'traffic jam', 'traffic jam', 'traffic jam', 'traffic jam',
#        'traffic jam', 'traffic jam', 'traffic jam', 'traffic jam',
#        'traffic jam', 'traffic jam', 'traffic jam', 'traffic jam',
#        'train accident', 'train accident, with smoke', 'tropical cyclone',
#        'tropical cyclone', 'tropical cyclone', 'tropical cyclone',
#        'tropical cyclone', 'tropical cyclone', 'tropical cyclone',
#        'under construction', 'under construction', 'under construction',
#        'under construction', 'under construction', 'under construction',
#        'under construction', 'under construction', 'under construction',
#        'under construction', 'under construction', 'under construction',
#        'under construction', 'under construction', 'under construction',
#        'under construction', 'under construction', 'under construction',
#        'under construction', 'under construction', 'under construction',
#        'van accident', 'van accident', 'volcanic eruption',
#        'volcanic eruption', 'volcanic eruption', 'volcanic eruption',
#        'volcanic eruption', 'volcanic eruption', 'volcanic eruption',
#        'volcanic eruption', 'volcanic eruption',
#        'volcanic eruption, with smoke', 'wildfire', 'wildfire',
#        'wildfire', 'wildfire, with smoke', 'with smoke', 'with smoke',
#        'with smoke', 'with smoke', 'with smoke', 'with smoke',
#        'with smoke', 'with smoke', 'with smoke', 'with smoke',
#        'with smoke', 'with smoke', 'with smoke', 'with smoke'],
#       dtype=object)

# %%
incident_sample_counts = pd.Series(incident_samples).value_counts()
places_sample_counts = pd.Series(places_samples).value_counts()

grouped_incidents = df.groupby("incidents_list")
grouped_places = df.groupby("places_list")

sample_df = pd.DataFrame()

for i in incident_sample_counts.index:
    amount = incident_sample_counts[i]
    sub_df = grouped_incidents.get_group(i).sample(incident_sample_counts[i]) if len(grouped_incidents.get_group(i)) > amount else grouped_incidents.get_group(i)
    sample_df = pd.concat([sample_df, sub_df])

for i in places_sample_counts.index:
    amount = places_sample_counts[i]
    sub_df = grouped_places.get_group(i).sample(places_sample_counts[i]) if len(grouped_places.get_group(i)) > amount else grouped_places.get_group(i)
    sample_df = pd.concat([sample_df, sub_df])

sample_df
# Out:
#                                                        url  \
# 812453   https://mediad.publicbroadcasting.net/p/kajx/f...
# 294328   https://l450v.alamy.com/450v/2abh56e/snow-mash...
# 116893   https://www.reykjavikrentacar.is/media/1/reykj...
# 351578   https://i0.wp.com/www.ozarksfirst.com/wp-conte...
# 110563   https://mediad.publicbroadcasting.net/p/krwg/f...
# ...                                                    ...
# 725610   https://gwilson42.files.wordpress.com/2015/07/...
# 1292879  https://www.digbybrown.co.uk/sites/default/fil...
# 1057197  https://bloximages.chicago2.vip.townnews.com/h...
# 1243306  http://newtoncountyms.net/wp-content/uploads/2...
# 1021943  https://previews.agefotostock.com/previewimage...
#
#                                                  incidents  \
# 812453       {'snowslide avalanche': 0, 'snow covered': 1}
# 294328                                 {'snow covered': 1}
# 116893                                 {'snow covered': 1}
# 351578       {'snowslide avalanche': 0, 'snow covered': 1}
# 110563       {'snowslide avalanche': 0, 'snow covered': 1}
# ...                                                    ...
# 725610   {'blocked': 1, 'under construction': 0, 'traff...
# 1292879                          {'under construction': 1}
# 1057197  {'heavy rainfall': 1, 'storm surge': 1, 'lands...
# 1243306                {'fog': 0, 'under construction': 1}
# 1021943                {'hailstorm': 1, 'snow covered': 1}
#
#                                                     places  \
# 812453                        {'bridge': 0, 'mountain': 1}
# 294328                     {'mountain': 1, 'snowfield': 1}
# 116893                                      {'glacier': 1}
# 351578   {'glacier': 0, 'snowfield': 1, 'mountain': 0, ...
# 110563        {'valley': 1, 'snowfield': 1, 'mountain': 1}
# ...                                                    ...
# 725610   {'port': 0, 'sky': 1, 'power line': 1, 'highwa...
# 1292879     {'industrial area': 1, 'construction site': 1}
# 1057197                           {'glacier': 0, 'dam': 1}
# 1243306                  {'landfill': 0, 'desert road': 1}
# 1021943           {'farm': 1, 'snowfield': 1, 'forest': 0}
#
#                                      image_id  \
# 812453   29174a33-d860-405e-a856-bb3cbe9b7db8
# 294328   aae9c71b-d741-459d-bac9-434f61decf5a
# 116893   420142ad-fc59-420c-99d8-801e783f259d
# 351578   b917cf67-cbb0-493d-973a-8bd1c886416a
# 110563   63280692-cad9-4d42-9d6b-b8f29e98b18e
# ...                                       ...
# 725610   89ef8a45-5018-4ecf-aedd-a76c5e8ac5fd
# 1292879  b45db599-989c-48f1-bb17-4d0069ba6863
# 1057197  17fcba92-0c93-4064-a4f5-bd1723f9f215
# 1243306  f4e48ad2-9e3b-4fd5-920b-bf5da1aa0486
# 1021943  bc99f94a-1752-485e-a0c4-f0be91093cb5
#
#                                                 key  downloadable  \
# 812453           snow_avalanche_in_bridge_00060.jpg          True
# 294328               frozen_mountain_path_00030.jpg          True
# 116893           van_collision_in_glacier_00540.jpg          True
# 351578           boat_incident_in_glacier_00363.jpg          True
# 110563           snow_avalanche_in_valley_00102.jpg          True
# ...                                             ...           ...
# 725610                blocked_harbor_c3ca8fc4ff.jpg          True
# 1292879  ship_accident_in_industrial_area_00364.jpg          True
# 1057197        heavy_rain_in_glacier_61ae9044bb.jpg          True
# 1243306              fog_in_landfill_01a07a6863.jpg          True
# 1021943                snow_storm_in_farm_00568.jpg          True
#
#                                incidents_list  \
# 812453                           snow covered
# 294328                           snow covered
# 116893                           snow covered
# 351578                           snow covered
# 110563                           snow covered
# ...                                       ...
# 725610                                blocked
# 1292879                    under construction
# 1057197  flooded, heavy rainfall, storm surge
# 1243306                    under construction
# 1021943               hailstorm, snow covered
#
#                                          places_list
# 812453                                      mountain
# 294328                           mountain, snowfield
# 116893                                       glacier
# 351578                                     snowfield
# 110563                   mountain, snowfield, valley
# ...                                              ...
# 725610   construction site, highway, power line, sky
# 1292879           construction site, industrial area
# 1057197                                          dam
# 1243306                                  desert road
# 1021943                              farm, snowfield
#
# [1000 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the distrubution of incidents and places
incidents = sample_df["incidents_list"].str.split(", ").explode().value_counts()
places = sample_df["places_list"].str.split(", ").explode().value_counts()

fig, ax = plt.subplots(1, 2, figsize=(20, 20))
sns.barplot(x=incidents.values, y=incidents.index, ax=ax[0])
sns.barplot(x=places.values, y=places.index, ax=ax[1])
ax[0].set_title("Incidents distribution")
ax[1].set_title("Places distribution")
plt.show()

# %%
alternative_sample_df = df[(df["incidents_list"] != "unknown") & (df["places_list"] != "unknown")].sample(n).copy()

incidents = alternative_sample_df["incidents_list"].str.split(", ").explode().value_counts()
places = alternative_sample_df["places_list"].str.split(", ").explode().value_counts()

fig, ax = plt.subplots(1, 2, figsize=(20, 20))
sns.barplot(x=incidents.values, y=incidents.index, ax=ax[0])
sns.barplot(x=places.values, y=places.index, ax=ax[1])
ax[0].set_title("Incidents distribution")
ax[1].set_title("Places distribution")
plt.show()
