# %%
import pandas as pd
import numpy as np
import json

# %%
multi_label_name = "multi_label_train_status_codes"
export_name = "multi_label_train"
version = "v0.4"

# %%
df = pd.read_pickle("../data/"+multi_label_name+".pkl")
df
# Out:
#                                                        url  \
# 0        https://localtvwtkr.files.wordpress.com/2018/0...
# 1        https://www.earthmagazine.org/sites/earthmagaz...
# 2        https://s-media-cache-ak0.pinimg.com/originals...
# 3        https://m.gjcdn.net/screenshot-thumbnail/300x3...
# 4        http://nnimgt-a.akamaihd.net/transform/v1/crop...
# ...                                                    ...
# 1608667  https://upload.wikimedia.org/wikipedia/commons...
# 1608668  http://images.newindianexpress.com/uploads/use...
# 1608669  https://savepetesharbor.files.wordpress.com/20...
# 1608670  https://i1.ytimg.com/vi/pdyzTYH1L5Q/hqdefault.jpg
# 1608671  https://thumb9.shutterstock.com/display_pic_wi...
#
#                                                  incidents  \
# 0        {'snow covered': 1, 'ice storm': 0, 'hailstorm...
# 1                                           {'flooded': 1}
# 2                                    {'truck accident': 0}
# 3                                         {'hailstorm': 0}
# 4        {'blocked': 1, 'with smoke': 0, 'under constru...
# ...                                                    ...
# 1608667                                         {'fog': 1}
# 1608668                                {'snow covered': 1}
# 1608669            {'flooded': 0, 'under construction': 0}
# 1608670                                     {'on fire': 1}
# 1608671                                   {'landslide': 1}
#
#                                                     places  \
# 0                {'parking lot': 0, 'building outdoor': 1}
# 1         {'field': 0, 'street': 1, 'building outdoor': 0}
# 2                                                       {}
# 3                                                       {}
# 4        {'construction site': 0, 'skyscraper': 0, 'dow...
# ...                                                    ...
# 1608667                         {'street': 0, 'forest': 0}
# 1608668  {'port': 0, 'ocean': 0, 'glacier': 0, 'coast': 1}
# 1608669                                                 {}
# 1608670  {'industrial area': 1, 'downtown': 0, 'buildin...
# 1608671       {'desert': 0, 'forest road': 1, 'forest': 0}
#
#                                      image_id
# 0                                         404
# 1                                         404
# 2        e6a54564-0082-4a26-9df4-13fe39f8ec15
# 3                                         404
# 4                                         400
# ...                                       ...
# 1608667                                   403
# 1608668  93c26672-dba8-4f3c-ab66-9a426c9b05f8
# 1608669  aee52b54-05cc-444b-b410-e5b0ef870c74
# 1608670  c21faea6-5060-4f3f-9d2e-a8b65cfa0f74
# 1608671  80d7afe1-fb86-4925-8cb4-f0a25961c44b
#
# [1608672 rows x 4 columns]

# %%
if "key" not in df.columns:
    with open("../data/"+export_name+".json") as f:
        data = json.load(f)
    
    keys = data.keys()

    df["key"] = keys

df["key"] = df["key"].apply(lambda x: x.replace("/", "_"))

# %%
if "valid_image" not in df.columns:
    with open("../data/image_status.json") as f:
        data = json.load(f)
    
    df["valid_image"] = df["image_id"].apply(lambda x: data.get(x+".jpg", False))

df
# Out:
#                                                        url  \
# 0        https://localtvwtkr.files.wordpress.com/2018/0...
# 1        https://www.earthmagazine.org/sites/earthmagaz...
# 2        https://s-media-cache-ak0.pinimg.com/originals...
# 3        https://m.gjcdn.net/screenshot-thumbnail/300x3...
# 4        http://nnimgt-a.akamaihd.net/transform/v1/crop...
# ...                                                    ...
# 1608667  https://upload.wikimedia.org/wikipedia/commons...
# 1608668  http://images.newindianexpress.com/uploads/use...
# 1608669  https://savepetesharbor.files.wordpress.com/20...
# 1608670  https://i1.ytimg.com/vi/pdyzTYH1L5Q/hqdefault.jpg
# 1608671  https://thumb9.shutterstock.com/display_pic_wi...
#
#                                                  incidents  \
# 0        {'snow covered': 1, 'ice storm': 0, 'hailstorm...
# 1                                           {'flooded': 1}
# 2                                    {'truck accident': 0}
# 3                                         {'hailstorm': 0}
# 4        {'blocked': 1, 'with smoke': 0, 'under constru...
# ...                                                    ...
# 1608667                                         {'fog': 1}
# 1608668                                {'snow covered': 1}
# 1608669            {'flooded': 0, 'under construction': 0}
# 1608670                                     {'on fire': 1}
# 1608671                                   {'landslide': 1}
#
#                                                     places  \
# 0                {'parking lot': 0, 'building outdoor': 1}
# 1         {'field': 0, 'street': 1, 'building outdoor': 0}
# 2                                                       {}
# 3                                                       {}
# 4        {'construction site': 0, 'skyscraper': 0, 'dow...
# ...                                                    ...
# 1608667                         {'street': 0, 'forest': 0}
# 1608668  {'port': 0, 'ocean': 0, 'glacier': 0, 'coast': 1}
# 1608669                                                 {}
# 1608670  {'industrial area': 1, 'downtown': 0, 'buildin...
# 1608671       {'desert': 0, 'forest road': 1, 'forest': 0}
#
#                                      image_id  \
# 0                                         404
# 1                                         404
# 2        e6a54564-0082-4a26-9df4-13fe39f8ec15
# 3                                         404
# 4                                         400
# ...                                       ...
# 1608667                                   403
# 1608668  93c26672-dba8-4f3c-ab66-9a426c9b05f8
# 1608669  aee52b54-05cc-444b-b410-e5b0ef870c74
# 1608670  c21faea6-5060-4f3f-9d2e-a8b65cfa0f74
# 1608671  80d7afe1-fb86-4925-8cb4-f0a25961c44b
#
#                                                    key  valid_image
# 0                winter_storm_in_parking_lot_00361.jpg        False
# 1                coastal_flood_in_field_road_00296.jpg        False
# 2        track_crash_in_library_outdoor_af9881c12a.jpg         True
# 3                      hailstorm_in_dam_b6ec75ec51.jpg        False
# 4             blocked_construction_site_094b6eef1a.jpg        False
# ...                                                ...          ...
# 1608667              van_wreck_in_alley_564c55a4a6.jpg        False
# 1608668               oil_spill_in_port_3bfea2121a.jpg         True
# 1608669                       blocked_harbor_00122.jpg         True
# 1608670         wild_fire_in_industrial_area_00230.jpg         True
# 1608671   mudslide_in_desert_vegetation_e058c1d8b9.jpg         True
#
# [1608672 rows x 6 columns]

# %%
df["downloadable"] = df["image_id"].apply(lambda x: x.isnumeric() == False and x != "-1")
df
# Out:
#                                                        url  \
# 0        https://localtvwtkr.files.wordpress.com/2018/0...
# 1        https://www.earthmagazine.org/sites/earthmagaz...
# 2        https://s-media-cache-ak0.pinimg.com/originals...
# 3        https://m.gjcdn.net/screenshot-thumbnail/300x3...
# 4        http://nnimgt-a.akamaihd.net/transform/v1/crop...
# ...                                                    ...
# 1608667  https://upload.wikimedia.org/wikipedia/commons...
# 1608668  http://images.newindianexpress.com/uploads/use...
# 1608669  https://savepetesharbor.files.wordpress.com/20...
# 1608670  https://i1.ytimg.com/vi/pdyzTYH1L5Q/hqdefault.jpg
# 1608671  https://thumb9.shutterstock.com/display_pic_wi...
#
#                                                  incidents  \
# 0        {'snow covered': 1, 'ice storm': 0, 'hailstorm...
# 1                                           {'flooded': 1}
# 2                                    {'truck accident': 0}
# 3                                         {'hailstorm': 0}
# 4        {'blocked': 1, 'with smoke': 0, 'under constru...
# ...                                                    ...
# 1608667                                         {'fog': 1}
# 1608668                                {'snow covered': 1}
# 1608669            {'flooded': 0, 'under construction': 0}
# 1608670                                     {'on fire': 1}
# 1608671                                   {'landslide': 1}
#
#                                                     places  \
# 0                {'parking lot': 0, 'building outdoor': 1}
# 1         {'field': 0, 'street': 1, 'building outdoor': 0}
# 2                                                       {}
# 3                                                       {}
# 4        {'construction site': 0, 'skyscraper': 0, 'dow...
# ...                                                    ...
# 1608667                         {'street': 0, 'forest': 0}
# 1608668  {'port': 0, 'ocean': 0, 'glacier': 0, 'coast': 1}
# 1608669                                                 {}
# 1608670  {'industrial area': 1, 'downtown': 0, 'buildin...
# 1608671       {'desert': 0, 'forest road': 1, 'forest': 0}
#
#                                      image_id  \
# 0                                         404
# 1                                         404
# 2        e6a54564-0082-4a26-9df4-13fe39f8ec15
# 3                                         404
# 4                                         400
# ...                                       ...
# 1608667                                   403
# 1608668  93c26672-dba8-4f3c-ab66-9a426c9b05f8
# 1608669  aee52b54-05cc-444b-b410-e5b0ef870c74
# 1608670  c21faea6-5060-4f3f-9d2e-a8b65cfa0f74
# 1608671  80d7afe1-fb86-4925-8cb4-f0a25961c44b
#
#                                                    key  valid_image  \
# 0                winter_storm_in_parking_lot_00361.jpg        False
# 1                coastal_flood_in_field_road_00296.jpg        False
# 2        track_crash_in_library_outdoor_af9881c12a.jpg         True
# 3                      hailstorm_in_dam_b6ec75ec51.jpg        False
# 4             blocked_construction_site_094b6eef1a.jpg        False
# ...                                                ...          ...
# 1608667              van_wreck_in_alley_564c55a4a6.jpg        False
# 1608668               oil_spill_in_port_3bfea2121a.jpg         True
# 1608669                       blocked_harbor_00122.jpg         True
# 1608670         wild_fire_in_industrial_area_00230.jpg         True
# 1608671   mudslide_in_desert_vegetation_e058c1d8b9.jpg         True
#
#          downloadable
# 0               False
# 1               False
# 2                True
# 3               False
# 4               False
# ...               ...
# 1608667         False
# 1608668          True
# 1608669          True
# 1608670          True
# 1608671          True
#
# [1608672 rows x 7 columns]

# %%
df["incidents_list"] = df["incidents"].apply(lambda x: ", ".join(sorted([k for k, v in dict(x).items() if v == 1])))
df["incidents_list"] = df["incidents_list"].replace("", "unknown")

df["places_list"] = df["places"].apply(lambda x: ", ".join(sorted([k for k, v in dict(x).items() if v == 1])))
df["places_list"] = df["places_list"].replace("", "unknown")

df
# Out:
#                                                        url  \
# 0        https://localtvwtkr.files.wordpress.com/2018/0...
# 1        https://www.earthmagazine.org/sites/earthmagaz...
# 2        https://s-media-cache-ak0.pinimg.com/originals...
# 3        https://m.gjcdn.net/screenshot-thumbnail/300x3...
# 4        http://nnimgt-a.akamaihd.net/transform/v1/crop...
# ...                                                    ...
# 1608667  https://upload.wikimedia.org/wikipedia/commons...
# 1608668  http://images.newindianexpress.com/uploads/use...
# 1608669  https://savepetesharbor.files.wordpress.com/20...
# 1608670  https://i1.ytimg.com/vi/pdyzTYH1L5Q/hqdefault.jpg
# 1608671  https://thumb9.shutterstock.com/display_pic_wi...
#
#                                                  incidents  \
# 0        {'snow covered': 1, 'ice storm': 0, 'hailstorm...
# 1                                           {'flooded': 1}
# 2                                    {'truck accident': 0}
# 3                                         {'hailstorm': 0}
# 4        {'blocked': 1, 'with smoke': 0, 'under constru...
# ...                                                    ...
# 1608667                                         {'fog': 1}
# 1608668                                {'snow covered': 1}
# 1608669            {'flooded': 0, 'under construction': 0}
# 1608670                                     {'on fire': 1}
# 1608671                                   {'landslide': 1}
#
#                                                     places  \
# 0                {'parking lot': 0, 'building outdoor': 1}
# 1         {'field': 0, 'street': 1, 'building outdoor': 0}
# 2                                                       {}
# 3                                                       {}
# 4        {'construction site': 0, 'skyscraper': 0, 'dow...
# ...                                                    ...
# 1608667                         {'street': 0, 'forest': 0}
# 1608668  {'port': 0, 'ocean': 0, 'glacier': 0, 'coast': 1}
# 1608669                                                 {}
# 1608670  {'industrial area': 1, 'downtown': 0, 'buildin...
# 1608671       {'desert': 0, 'forest road': 1, 'forest': 0}
#
#                                      image_id  \
# 0                                         404
# 1                                         404
# 2        e6a54564-0082-4a26-9df4-13fe39f8ec15
# 3                                         404
# 4                                         400
# ...                                       ...
# 1608667                                   403
# 1608668  93c26672-dba8-4f3c-ab66-9a426c9b05f8
# 1608669  aee52b54-05cc-444b-b410-e5b0ef870c74
# 1608670  c21faea6-5060-4f3f-9d2e-a8b65cfa0f74
# 1608671  80d7afe1-fb86-4925-8cb4-f0a25961c44b
#
#                                                    key  valid_image  \
# 0                winter_storm_in_parking_lot_00361.jpg        False
# 1                coastal_flood_in_field_road_00296.jpg        False
# 2        track_crash_in_library_outdoor_af9881c12a.jpg         True
# 3                      hailstorm_in_dam_b6ec75ec51.jpg        False
# 4             blocked_construction_site_094b6eef1a.jpg        False
# ...                                                ...          ...
# 1608667              van_wreck_in_alley_564c55a4a6.jpg        False
# 1608668               oil_spill_in_port_3bfea2121a.jpg         True
# 1608669                       blocked_harbor_00122.jpg         True
# 1608670         wild_fire_in_industrial_area_00230.jpg         True
# 1608671   mudslide_in_desert_vegetation_e058c1d8b9.jpg         True
#
#          downloadable incidents_list                 places_list
# 0               False   snow covered            building outdoor
# 1               False        flooded                      street
# 2                True        unknown                     unknown
# 3               False        unknown                     unknown
# 4               False        blocked  building outdoor, downtown
# ...               ...            ...                         ...
# 1608667         False            fog                     unknown
# 1608668          True   snow covered                       coast
# 1608669          True        unknown                     unknown
# 1608670          True        on fire             industrial area
# 1608671          True      landslide                 forest road
#
# [1608672 rows x 9 columns]

# %%
df.to_pickle("../data/"+export_name+"_"+version+".pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sebastiancelis/Documents/Master/WS 22:23/Data Science Project/IncidentsDataset/preprocessing/process_status_codes_dataset.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/sebastiancelis/Documents/Master/WS%2022%3A23/Data%20Science%20Project/IncidentsDataset/preprocessing/process_status_codes_dataset.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> df.to_pickle("../data/"+export_name+"_"+version+".pkl")
#       <a href='vscode-notebook-cell:/Users/sebastiancelis/Documents/Master/WS%2022%3A23/Data%20Science%20Project/IncidentsDataset/preprocessing/process_status_codes_dataset.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> df = pd.read_pickle("../data/"+export_name+"_"+version+".pkl")
#       <a href='vscode-notebook-cell:/Users/sebastiancelis/Documents/Master/WS%2022%3A23/Data%20Science%20Project/IncidentsDataset/preprocessing/process_status_codes_dataset.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> df[(df["valid_image"] == False) & (df["downloadable"] == True)]
#
# NameError: name 'df' is not defined

# %%
df = pd.read_pickle("../data/"+export_name+"_"+version+".pkl")

usable_df = df[df["valid_image"] == True].copy()

ignore_incidents = ["unknown", "earthquake", "snow covered"]

# Check each incident in the incidents_list split with , and check if it is in ignore_incidents
usable_df = usable_df[~usable_df["incidents_list"].apply(lambda x: any([i in ignore_incidents for i in x.split(", ")]))].copy()
usable_df["incidents_list"].value_counts()
# Out:
# flooded                                                               40235
# fog                                                                   30320
# drought                                                               25354
# under construction                                                    23924
# car accident                                                          20995
#                                                                       ...
# dust devil, fog, on fire                                                  1
# blocked, bus accident, car accident, mudslide mudflow                     1
# damaged, flooded, oil spill, on fire                                      1
# burned, collapsed, nuclear explosion, oil spill, on fire, wildfire        1
# collapsed, ice storm, storm surge                                         1
# Name: incidents_list, Length: 3481, dtype: int64
